# %%
import yfinance as yf
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import numpy as np
import seaborn as sns
import pandas as pd
import os, sys
import sys
sys.path.append('../module')
sys.path.append('../database')

import stockpy as st

# %%
df = pd.read_csv('../database/japan_stock_name_sheet.csv')
df_data_base = pd.read_csv('../database/japan_stock_netincome_2020.csv')

# %%
record = df_data_base.A
list_df = pd.DataFrame()

# %%
a_1 = '1d'
b_1 = '2020-4-8'
c_1 = '2020-5-8'

a_2 = '1d'
b_2 = '2020-3-8'
c_2 = '2020-4-8'

# %%
len(df.A)
# Out:
# 3869

# %%
list_df = st.kabu_japan(df, df_data_base, len(df.A), a_1, b_1, c_1, a_2, b_2, c_2)
# Out:
# Now 0 in 3869
# Now 1 in 3869
# Now 2 in 3869
# Now 3 in 3869
# Now 4 in 3869
# Now 5 in 3869
# Now 6 in 3869
# Now 7 in 3869
# Now 8 in 3869
# Now 9 in 3869
# Now 10 in 3869
# Now 11 in 3869
# Now 12 in 3869
# Now 13 in 3869
# 14
# Now 14 in 3869
# Now 15 in 3869
# Now 16 in 3869
# Now 18 in 3869
# Now 19 in 3869
# Now 20 in 3869
# Now 21 in 3869
# Now 22 in 3869
# Now 23 in 3869
# Now 24 in 3869
# Now 25 in 3869
# Now 26 in 3869
# Now 27 in 3869
# - 1438.T: No data found, symbol may be delisted
# - 1438.T: No data found, symbol may be delisted
# Now 28 in 3869
# Now 29 in 3869
# - 1444.T: No data found, symbol may be delisted
# - 1444.T: No data found, symbol may be delisted
# Now 31 in 3869
# Now 32 in 3869
# - 1449.T: No data found, symbol may be delisted
# - 1449.T: No data found, symbol may be delisted
# Now 35 in 3869
# Now 36 in 3869
# Now 37 in 3869
# Now 38 in 3869
# Now 39 in 3869
# Now 40 in 3869
# Now 41 in 3869
# Now 42 in 3869
# Now 43 in 3869
# Now 45 in 3869
# ...

# %%
list_df
# Out:
#    code         point  netincome      tilt  tilt_pre  tilt_diff        Volume  \
# 0  1407 -1.154699e+05  -0.262806  0.017305  0.008731   0.008574  2.176889e+05
# 0  2146  2.574350e+05   0.384443  0.015540 -0.021569   0.037109  1.599056e+06
# 0  2154  3.371581e+04   0.166138  0.016436 -0.013564   0.030000  3.704111e+05
# 0  3264  4.275147e+04   0.056579  0.017469 -0.004810   0.022279  9.636556e+05
# 0  3678  6.294854e+02   0.001085  0.015056  0.009559   0.005498  2.118056e+05
# 0  3835  6.318877e+04   0.170085  0.017709 -0.000079   0.017788  3.731778e+05
# 0  3854  1.136096e+05   0.274007  0.016601  0.002312   0.014289  3.568889e+05
# 0  3900 -1.707071e+06  -1.992063  0.018737  0.011276   0.007461  3.412278e+05
# 0  3906  2.855474e+05   1.062500  0.015209 -0.009532   0.024740  4.371833e+05
# 0  3939  9.977439e+04   0.187675  0.015437  0.001127   0.014310  4.928333e+05
# 0  3962  7.139047e+04   0.220732  0.018320 -0.011220   0.029540  5.215167e+05
# ...

# %%
df_s = list_df.sort_values('point', ascending=False)
mylist = list(range(1,(len(df_s)+1)))
df_s['rank'] = mylist
#df_s.to_csv("test.csv")

# %%
df_s.to_csv("C:\\Share\\programing_output\\japan_ana_v0_1.csv")
